# %% [markdown]
# // Array of student objects
# const students = [
#   { name: "Rahul", age: 20 },
#   { name: "Priya", age: 19 },
#   { name: "Amit", age: 21 },
#   { name: "Sneha", age: 20 }
# ];
#
# // Using forEach to display student names
# students.forEach(student => {
#   console.log(student.name);
# });
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# const originalPrices = [100, 250, 500, 750, 1000];
#
# // Using map to add 18% GST
# const pricesWithGST = originalPrices.map(price => {
#   return price + (price * 0.18);
# });
#
# console.log(pricesWithGST);
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# const students = [
#   { name: "Raj", marks: 85 },
#   { name: "Sita", marks: 92 },
#   { name: "Vikram", marks: 78 },
#   { name: "Meera", marks: 88 }
# ];
#
# const topStudents = students.filter(student => {
#   return student.marks > 80;
# });
#
# console.log(topStudents);
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# const students = [
#   { name: "Raj", marks: 85 },
#   { name: "Sita", marks: 92 },
#   { name: "Vikram", marks: 78 },
#   { name: "Meera", marks: 88 }
# ];
#
# const topStudents = students.filter(student => {
#   return student.marks > 80;
# });
#
# console.log(topStudents);

# %% [markdown]
# // Array of book objects
# const books = [
#   { title: "Gitanjali", author: "Rabindranath Tagore" },
#   { title: "Harry Potter", author: "J.K. Rowling" },
#   { title: "The God of Small Things", author: "Arundhati Roy" },
#   { title: "Midnight's Children", author: "Salman Rushdie" }
# ];
#
# // Using find to locate the book
# const foundBook = books.find(book => book.title === "Harry Potter");
#
# if (foundBook) {
#   console.log("Author:", foundBook.author);
# } else {
#   console.log("Book not found");
# }

# %% [markdown]
# // Array of employee objects
# const employees = [
#   { name: "Rajesh", salary: 45000 },
#   { name: "Priya", salary: 55000 },
#   { name: "Amit", salary: 40000 },
#   { name: "Kavya", salary: 60000 }
# ];
#
# // Sorting by salary in descending order
# const sortedEmployees = employees.sort((a, b) => b.salary - a.salary);
#
# console.log(sortedEmployees);

# %% [markdown]
# // Shopping cart with items
# const cart = [
#   { name: "Laptop", price: 50000, quantity: 1 },
#   { name: "Mouse", price: 500, quantity: 2 },
#   { name: "Keyboard", price: 1500, quantity: 1 },
#   { name: "Monitor", price: 15000, quantity: 1 }
# ];
#
# // Total value of all items
# const totalValue = cart.reduce((total, item) => {
#   return total + item.price * item.quantity;
# }, 0);
#
# // Most expensive single item
# const mostExpensive = cart.reduce((max, item) => {
#   return item.price > max.price ? item : max;
# });
#
# console.log("Total Cart Value:", totalValue);
# console.log("Most Expensive Item:", mostExpensive.name);

# %% [markdown]
# // Array of colors
# const colors = ["red", "blue", "green", "yellow", "purple"];
#
# // Destructuring first two colors
# const [firstColor, secondColor] = colors;
#
# console.log(firstColor);  // red
# console.log(secondColor); // blue

# %% [markdown]
# // Student object
# const student = {
#   name: "Arjun",
#   age: 20,
#   marks: 85,
#   city: "Mumbai"
# };
#
# // Destructuring and renaming marks to score
# const { name, age, marks: score } = student;
#
# console.log(name);  // Arjun
# console.log(age);   // 20
# console.log(score); // 85

# %% [markdown]
# function calculateTotal(...prices) {
#   return prices.reduce((sum, price) => sum + price, 0);
# }
#
# console.log(calculateTotal(100, 200, 50));  // 350
# console.log(calculateTotal(500, 1000));     // 1500

# %% [markdown]
# const classA = ["Rahul", "Priya", "Amit"];
# const classB = ["Sneha", "Vikram", "Pooja"];
#
# const allStudents = [...classA, ...classB];
#
# console.log(allStudents);

# %% [markdown]
# const basicInfo = { name: "Rohan", age: 20 };
# const marksInfo = { math: 85, english: 90 };
#
# const studentDetails = { ...basicInfo, ...marksInfo };
#
# console.log(studentDetails);
